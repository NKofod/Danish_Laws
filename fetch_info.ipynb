# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By 
import time 
import json

# %%
with open("Results.json","r") as infile:
    links = json.load(infile)

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
with open("Info.json","r") as infile:
    out_dict = json.load(infile)

# %%
count = 0
for link in links: 
    count += 1 
    url = f"https://www.retsinformation.dk{link}"
    if url in out_dict.keys():
        continue 
    print(count)
    driver.get(url)
    time.sleep(3)
    elem = driver.find_element(By.CLASS_NAME,"metadata-box-content")
    info = elem.get_attribute('innerHTML')
    out_dict[url] = str(info) 
    if count % 10 == 0:
        with open("Info.json","w") as outfile: 
            json.dump(out_dict,outfile,indent=4,ensure_ascii=False)
# Out:
# 8401
# 8402
# 8403
# 8404
# 8405
# 8406
# 8407
# 8408
# 8409
# 8410
# 8411
# 8412
# 8413
# 8414
# 8415
# 8416
# 8417
# 8418
# 8419
# 8420
# 8421
# 8422
# 8423
# 8424
# 8425
# 8426
# 8427
# 8428
# 8429
# 8430
# 8431
# 8432
# 8433
# 8434
# 8435
# 8436
# 8437
# 8438
# 8439
# 8440
# 8441
# 8442
# 8443
# 8444
# 8445
# 8446
# 8447
# 8448
# 8449
# 8450
# 8451
# 8452
# 8453
# 8454
# 8455
# 8456
# 8457
# 8458
# 8459
# 8460
# 8461
# 8462
# 8463
# 8464
# 8465
# 8466
# 8467
# 8468
# 8469
# 8470
# 8471
# 8472
# 8473
# 8474
# 8475
# 8476
# 8477
# 8478
# 8479
# 8480
# 8481
# 8482
# 8483
# 8484
# 8485
# 8486
# 8487
# 8488
# 8489
# 8490
# 8491
# 8492
# 8493
# 8494
# 8495
# 8496
# 8497
# 8498
# 8499
# 8500
# 8501
# 8502
# 8503
# 8504
# 8505
# 8506
# 8507
# 8508
# 8509
# 8510
# 8511
# 8512
# 8513
# 8514
# 8515
# 8516
# 8517
# 8518
# 8519
# 8520
# 8521
# 8522
# 8523
# 8524
# 8525
# 8526
# 8527
# 8528
# 8529
# 8530
# 8531
# 8532
# 8533
# 8534
# 8535
# 8536
# 8537
# 8538
# 8539
# 8540
# 8541
# 8542
# 8543
# 8544
# 8545
# 8546
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/kofod/Desktop/Danish_Laws/fetch_info.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/fetch_info.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> print(count)
#       <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/fetch_info.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> driver.get(url)
# ----> <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/fetch_info.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> time.sleep(3)
#      <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/fetch_info.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a> elem = driver.find_element(By.CLASS_NAME,"metadata-box-content")
#      <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/fetch_info.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> info = elem.get_attribute('innerHTML')
#
# KeyboardInterrupt:

# %%
import requests 
from bs4 import BeautifulSoup as Soup 
import time
import json

# %%
base_url = "https://www.retsinformation.dk/eli/accn/"

# %%
with open("log.json","r") as infile: 
    checked = json.load(infile)

# %%
for level in ["A","B","C"]:
    for year in range(1900,2024):
        for num in range(0,10000000):
            try: 
                tmp_url = f"{base_url}{level}{year}{num:07d}/xml"
                if tmp_url in checked:
                    continue 
                
                print(tmp_url)
                tmp_req = requests.get(tmp_url)
                tmp_soup = Soup(tmp_req.content)
                print(tmp_soup.text)
                if "No document found matching ELI request" != tmp_soup.text: 
                    print(tmp_soup)
                checked.append(tmp_url)
            except KeyboardInterrupt:
                with open("log.json","w") as outfile: 
                    json.dump(checked,outfile,indent=4,ensure_ascii=False)
# Out:
# https://www.retsinformation.dk/eli/accn/A19000000000/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000001/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000002/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000003/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000004/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000005/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000006/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000007/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000008/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000009/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000010/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000011/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000012/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000013/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000014/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000015/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000016/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000017/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000018/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000019/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000020/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000021/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000022/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000023/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000024/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000025/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000026/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000027/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000028/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000029/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000030/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000031/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000032/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000033/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000034/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000035/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000036/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000037/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000038/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000039/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000040/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000041/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000042/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000043/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000044/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000045/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000046/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000047/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000048/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000049/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000050/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000051/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000052/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000053/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000054/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000055/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000056/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000057/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000058/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000059/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000060/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000061/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000062/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000063/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000064/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000065/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000066/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000067/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000068/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000069/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000070/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000071/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000072/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000073/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000074/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000075/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000076/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000077/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000078/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000079/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000080/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000081/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000082/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000083/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000084/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000085/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000086/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000087/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000088/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000089/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000090/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000091/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000092/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000093/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000094/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000095/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000096/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000097/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000098/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000099/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000100/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000101/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000102/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000103/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000104/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000105/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000106/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000107/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000108/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000109/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000110/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000111/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000112/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000113/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000114/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000115/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000116/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000117/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000118/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000119/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000120/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000121/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000122/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000123/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000124/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000125/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000126/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000127/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000128/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000129/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000130/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000131/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000132/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000133/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000134/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000135/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000136/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000137/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000138/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000139/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000140/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000141/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000142/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000143/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000144/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000145/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000146/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000147/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000148/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000149/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000150/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000151/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000152/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000153/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000154/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000155/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000156/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000157/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000158/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000159/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000160/xml
# No document found matching ELI request
# https://www.retsinformation.dk/eli/accn/A19000000161/xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/kofod/Desktop/Danish_Laws/test.ipynb Cell 3 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/test.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> tmp_url = f"{base_url}{level}{year}{num:07d}/xml"
#       <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/test.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> print(tmp_url)
# ----> <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/test.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> tmp_req = requests.get(tmp_url)
#       <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/test.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> tmp_soup = Soup(tmp_req.content)
#       <a href='vscode-notebook-cell:/home/kofod/Desktop/Danish_Laws/test.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> print(tmp_soup.text)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 # Trigger any extra validation we need to do.
#     381 try:
# --> 382     self._validate_conn(conn)
#     383 except (SocketTimeout, BaseSSLError) as e:
#     384     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     385     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1012, in HTTPSConnectionPool._validate_conn(self, conn)
#    1010 # Force connect early to allow us to validate the connection.
#    1011 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1012     conn.connect()
#    1014 if not conn.is_verified:
#    1015     warnings.warn(
#    1016         (
#    1017             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1022         InsecureRequestWarning,
#    1023     )
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     402 if (
#     403     not self.ca_certs
#     404     and not self.ca_cert_dir
#    (...)
#     407     and hasattr(context, "load_default_certs")
#     408 ):
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#     427 if (
#     428     default_ssl_context
#     429     and self.ssl_version is None
#     430     and hasattr(self.sock, "version")
#     431     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     432 ):
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:

# %%
# Out:
# <!DOCTYPE html>
# <html lang="da" prefix="
#     og: http://ogp.me/ns#
#     eli: http://data.europa.eu/eli/ontology#
#     iana: http://www.iana.org/">
# <!-- for a list of additionally recognized default prefixes in RDFa see: https://www.w3.org/2011/rdfa-context/rdfa-1.1 -->
# <head>
# <meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,minimum-scale=1,shrink-to-fit=no" name="viewport"/><meta content="#000000" name="theme-color"/><base href="/"/><link href="/manifest.json" rel="manifest"/><link href="/favicon.ico" rel="shortcut icon"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><meta content="0AmFBlK2MhaV9Fbzlz1gRhvs2-EwECbIh9N1VgnTuUg" name="google-site-verification"/><meta content="_2HNkmPtogIXF9YwHTNLc3bvBDb_Btz3c1gfM2qNflQ" name="google-site-verification"/><title>Retsinformation</title><script defer="defer" src="/static/js/main.c5623b87.js"></script><link href="/static/css/main.c7551e1a.css" rel="stylesheet"/>
# <meta content="Retsinformation" property="og:site_name"/>
# <meta content="Retsinformation" property="og:title"/>
# <meta content="http://www.retsinformation.dk/documents?dl=2022-03-13T16%3A38%3A04&amp;dt=10&amp;dt=1480&amp;dt=20&amp;dt=30&amp;dt=40&amp;dt=50&amp;dt=90&amp;dt=120&amp;dt=270&amp;dt=60&amp;dt=100&amp;dt=80&amp;dt=110&amp;dt=130&amp;dt=140&amp;dt=150&amp;dt=160&amp;dt=170&amp;dt=180&amp;dt=200&amp;dt=210&amp;dt=220&amp;dt=1510&amp;dt=1490&amp;dt=-10&amp;o=80" property="og:url"/>
# <meta content="http://www.retsinformation.dk/ms-icon-310x310.png" property="og:image"/>
# <meta property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta property="og:article:author"/>
# <meta content="Retsinformation.dk er indgangen til det fælles statslige retsinformationssystem, der giver adgang til alle gældende love, bekendtgørelser og cirkulærer
#           m.v. Der er også adgang til Folketingets dokumenter og beretninger fra Folketingets Ombudsmand." name="description"/>
# </head>
# <body>
# <noscript>You need to enable JavaScript to run this app.</noscript><div id="root"></div>
# </body>
# </html>
# <!-- Server: 01 -->
